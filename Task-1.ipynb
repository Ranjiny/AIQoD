# %%
#Install necessary libraries
# !pip install pandas pymongo langchain langchain_community llama-cpp-python llama-index llama-index-embeddings-huggingface
# Out:
# Requirement already satisfied: pandas in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (2.2.3)
# Requirement already satisfied: pymongo in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (4.12.1)
# Requirement already satisfied: langchain in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (0.3.25)
# Requirement already satisfied: langchain_community in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (0.3.23)
# Requirement already satisfied: llama-cpp-python in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (0.3.9)
# Requirement already satisfied: llama-index in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (0.12.35)
# Requirement already satisfied: llama-index-embeddings-huggingface in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (0.5.4)
# Requirement already satisfied: numpy>=1.26.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from pandas) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from pymongo) (2.7.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.58 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from langchain) (0.3.59)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from langchain) (0.3.42)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from langchain) (2.11.4)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from langchain) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from langchain_community) (3.11.18)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from langchain_community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from langchain_community) (2.9.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from langchain_community) (0.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from llama-cpp-python) (4.13.2)
# Requirement already satisfied: diskcache>=5.6.1 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from llama-cpp-python) (5.6.3)
# Requirement already satisfied: jinja2>=2.11.3 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from llama-cpp-python) (3.1.6)
# Requirement already satisfied: llama-index-agent-openai<0.5,>=0.4.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from llama-index) (0.4.7)
# Requirement already satisfied: llama-index-cli<0.5,>=0.4.1 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from llama-index) (0.4.1)
# Requirement already satisfied: llama-index-core<0.13,>=0.12.35 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from llama-index) (0.12.35)
# Requirement already satisfied: llama-index-embeddings-openai<0.4,>=0.3.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from llama-index) (0.6.11)
# Requirement already satisfied: llama-index-llms-openai<0.4,>=0.3.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from llama-index) (0.3.38)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.5,>=0.4.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from llama-index) (0.4.3)
# Requirement already satisfied: llama-index-program-openai<0.4,>=0.3.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-question-gen-openai<0.4,>=0.3.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from llama-index) (0.3.0)
# Requirement already satisfied: llama-index-readers-file<0.5,>=0.4.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from llama-index) (0.4.7)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from llama-index) (0.4.0)
# Requirement already satisfied: nltk>3.8.1 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from llama-index) (3.9.1)
# Requirement already satisfied: huggingface-hub>=0.19.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.31.1)
# Requirement already satisfied: sentence-transformers>=2.6.1 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from llama-index-embeddings-huggingface) (4.1.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.20.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: filelock in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (24.2)
# Requirement already satisfied: tqdm>=4.42.1 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.67.1)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from jinja2>=2.11.3->llama-cpp-python) (3.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (1.33)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: openai>=1.14.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from llama-index-agent-openai<0.5,>=0.4.0->llama-index) (1.78.0)
# Requirement already satisfied: aiosqlite in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (0.21.0)
# Requirement already satisfied: banks<3,>=2.0.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (2.1.2)
# Requirement already satisfied: deprecated>=1.2.9.3 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (1.2.0)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (3.4.2)
# Requirement already satisfied: pillow>=9.0.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (11.2.1)
# Requirement already satisfied: tiktoken>=0.7.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (1.17.2)
# Requirement already satisfied: llama-cloud<0.2.0,>=0.1.13 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (0.1.19)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index) (4.13.4)
# Requirement already satisfied: pypdf<6.0.0,>=5.1.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index) (5.4.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from llama-index-readers-llama-parse>=0.4.0->llama-index) (0.6.22)
# Requirement already satisfied: click in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from nltk>3.8.1->llama-index) (8.1.8)
# Requirement already satisfied: joblib in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from nltk>3.8.1->llama-index) (1.5.0)
# Requirement already satisfied: regex>=2021.8.3 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from nltk>3.8.1->llama-index) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (1.1.0)
# Requirement already satisfied: six>=1.5 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from requests<3,>=2->langchain) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from requests<3,>=2->langchain) (2025.4.26)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (4.51.3)
# Requirement already satisfied: torch>=1.11.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.7.0)
# Requirement already satisfied: scikit-learn in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.6.1)
# Requirement already satisfied: scipy in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.15.3)
# Requirement already satisfied: greenlet>=1 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.2)
# Requirement already satisfied: griffe in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.35->llama-index) (1.7.3)
# Requirement already satisfied: platformdirs in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.35->llama-index) (4.3.8)
# Requirement already satisfied: soupsieve>1.2 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.5,>=0.4.0->llama-index) (2.7)
# Requirement already satisfied: anyio in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: httpcore==1.* in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.58->langchain) (3.0.0)
# Requirement already satisfied: llama-cloud-services>=0.6.22 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (0.6.22)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index) (0.9.0)
# Requirement already satisfied: sniffio in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index) (1.3.1)
# Requirement already satisfied: sympy>=1.13.3 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.14.0)
# Requirement already satisfied: setuptools in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (80.4.0)
# Requirement already satisfied: colorama in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.4.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.5.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.1.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from scikit-learn->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.3.0)
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\ranjiny\guvi_python\aiqod\myenv\lib\site-packages (from requests) (2025.4.26)
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#Step 1 : CSV Data Management
# Load CSV data into MongoDB
import pandas as pd
from pymongo import MongoClient

#Function to load the sample data to the Nosql DB
def load_csv_mongodb(path):
    df = pd.read_csv(path)
    #data cleaning
    df['Discount'] = df['Discount'].str.replace('%', '').astype(float)
    df['LaunchDate'] = pd.to_datetime(df['LaunchDate'], dayfirst=True, errors='coerce')
    print(df.info())
    print(df)
    #provide the necessary client,db,and collection names
    client = MongoClient('your_mongo_uri') #replace with your mongo url
    db = client['AIQoD']
    collection = db['Products']
    #delete and insert into collections
    collection.delete_many({})
    collection.insert_many(df.to_dict(orient='records'))
    client.close()
    
    print(f"Inserted {len(df)} documents into MongoDB.")
    return

# %%
#Step 2: Dynamic Query Generation using LLM
import requests
import json
import ast
#Use llama3.2 to generate a NoSql query givne the user input

def generate_query(user_query,path):
    

    df = pd.read_csv(path)
    query = f"""
    Write a python MongoDB query in the exact format: db.collection.find({{ "condition":{{"field": {{ "operator": value }}}} }})
    Find documents where: {user_query}
    Output ONLY the complete db.collection.find() statement with nothing else.
    Note: {df.columns} are  the column names
    """


    data = {
        "model": "llama3.2",
        "prompt": query,
        "stream": True  # This is the default, but just to be explicit
    }

    response = requests.post("http://localhost:11434/api/generate", json=data, stream=True)

    # Read and decode line-by-line (each line is a JSON object)
    generated_text = ""
    for line in response.iter_lines():
        if line:
            part = json.loads(line.decode("utf-8"))
            generated_text += part.get("response", "")


    print(generated_text)

    #Strip the data and create a dictionary for quering collections
     
    try:
        query_start = generated_text.find("find(") + len("find(")
        query_end = generated_text.rfind(")")
        query_str = generated_text[query_start:query_end].strip()
        #query_dict = ast.literal_eval(query_str)
        query_dict = json.loads(query_str)
        print(query_dict)
    except Exception as e:
        print(f"Error parsing query: {e}")
        query_dict = {}
    print(query_dict)

    return query_dict,generated_text

# %%
from llama_index.core import Document
from pymongo.mongo_client import MongoClient
from llama_index.vector_stores.mongodb import MongoDBAtlasVectorSearch
from llama_index.core.indices.vector_store.base import VectorStoreIndex
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.core import StorageContext
from llama_index.llms.ollama import Ollama
from llama_index.core import Settings

#provide the mongourl,db,collection as needed
def llama_index_mongodb(query_dict,user_query,path,response):
    df = pd.read_csv(path)#give the file path
    # Create a MongoClient
    client = MongoClient('your_mongo_uri')

    # Select the database and collection
    db = client['AIQoD'] #enter your db name
    collection = db['Products'] #enter your collections name

    # Get all documents (cursor is exhausted after first iteration)
    documents = list(collection.find({}))
    print(f'Loaded {len(documents)} documents')

    Settings.llm = Ollama(
        model="llama3.2",  
        base_url="http://localhost:11434",  
        request_timeout=60.0
    )

    embed_model = HuggingFaceEmbedding(model_name="all-MiniLM-L6-v2")
    Settings.embed_model = embed_model
    
    
    # Execute query and convert to DataFrame immediately (cursor exhausts after iteration)
    #results = list(collection.find(query_dict))

    # Convert to LlamaIndex Document format
    documents = [
        Document(text=str(doc))  # You can customize how the doc is formatted
        for doc in documents
    ]

    #print(documents)

    index = VectorStoreIndex.from_documents(documents)

    # Run a query
    query_engine = index.as_query_engine()
    results = query_engine.query(response)
    #print(results)


    #print the results if any matching records found in collections using regular quring method
    if results:
        df=pd.DataFrame(results)
        df = df.drop(df.columns[0], axis=1)
        # Ask the user what they want to do
        print("\n What would you like to do with the retrieved data?")
        print("1. Display the data")
        print("2. Save the data as CSV")
        choice = input("Enter 1 or 2: ")

        if choice == "1":
            print("\nRetrieved Data:\n")
            print(df)

        elif choice == "2":
            test_case_number = input("Enter test case number (e.g., 1 for test_case1.csv): ")
            filename = f"test_case{test_case_number}.csv"
            df.to_csv(filename, index=False)
            print(f"\n Data saved to: {filename}")

        else:
            print(" Invalid choice. Please enter 1 or 2.")

    #Setup indeces for each document  
    llama_documents=[]
    fields_to_include=['ProductID','ProductName','Category','Price','Rating','ReviewCount','Stock','Discount'
                   ,'Brand','LaunchDate']

    for doc in documents:
        metadata = {key: doc.get(key, None) for key in fields_to_include}
        llama_doc=Document(text="",metadata=metadata)
        llama_documents.append(llama_doc)

    
    # Ensure you have the MongoDB URI with appropriate credentials
    mongo_uri = 'you_mongo_uri' #give your uri
    mongodb_client = MongoClient(mongo_uri,    serverSelectionTimeoutMS=30000,  # 30 seconds for server selection
        socketTimeoutMS=60000,          # 60 seconds for socket operations
        connectTimeoutMS=30000,         # 30 seconds for connection
        waitQueueTimeoutMS=30000        # 30 seconds to wait for connection from pool
        )

    # Create an instance of MongoDBAtlasVectorSearch, vector index name should match that of the one created in mongoatlas
    vector_store = MongoDBAtlasVectorSearch(mongodb_client,    
                                            db_name="AIQoD",
                                            collection_name="Products",
                                            vector_index_name="vector_index" 
                                        

    )

    # now create an index from all the Documents and store them in Atlas
    storage_context = StorageContext.from_defaults(vector_store=vector_store)
    index = VectorStoreIndex.from_documents(
        llama_documents, storage_context=storage_context,
        show_progress=True, # this will show you a progress bar as the embeddings are created
    )
    # Create a VectorStoreIndex from the MongoDBAtlasVectorSearch instance
    index = VectorStoreIndex.from_vector_store(vector_store)

    query_engine = index.as_query_engine(
        vector_store_kwargs={
            "filter": query_dict,
            "search_kwargs": {
                "k": 10000,  # Number of results to return
                "score_threshold": 0  # Minimum similarity score
            }
        },
        response_mode="compact",      # Optional: makes output easier to parse
        return_source=True
    )
    result = query_engine.query(user_query)
    print(result)
    client.close()
    return

# %%
#main program to call the other functions 
path=r'..\AIQoD\sample_data.csv'
load_csv_mongodb(path)
user_query = input('Enter your query : ')
query_dictionary,response= generate_query(user_query,path)
llama_index_mongodb(query_dictionary,user_query,path,response)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ProductID    10 non-null     int64
#  1   ProductName  10 non-null     object
#  2   Category     10 non-null     object
#  3   Price        10 non-null     float64
#  4   Rating       10 non-null     float64
#  5   ReviewCount  10 non-null     int64
#  6   Stock        10 non-null     int64
#  7   Discount     10 non-null     float64
#  8   Brand        10 non-null     object
#  9   LaunchDate   10 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), int64(3), object(3)
# memory usage: 932.0+ bytes
# None
#    ProductID                  ProductName        Category   Price  Rating  \
# 0        101               Wireless Mouse     Electronics   25.99     4.5
# 1        102              Gaming Keyboard     Electronics   75.49     4.7
# 2        103  Noise Cancelling Headphones     Electronics  199.99     4.8
# 3        104                Running Shoes          Sports   49.99     4.3
# 4        105                   Smartwatch     Electronics  159.99     4.6
# 5        106                      Blender  Home & Kitchen   39.99     4.2
# 6        107                 Coffee Maker  Home & Kitchen   89.99     4.1
# 7        108                     Yoga Mat          Sports   29.99     4.4
# 8        109                     Smart TV     Electronics  399.99     4.7
# 9        110               Vacuum Cleaner  Home & Kitchen  129.99     4.3
#
#    ReviewCount  Stock  Discount     Brand LaunchDate
# 0          200    150      10.0  Logitech 2022-01-15
# 1          350     85       5.0   Corsair 2021-11-20
# 2          125     60      15.0      Sony 2021-09-05
# 3          500    200      20.0      Nike 2022-02-10
# 4          220     45      10.0     Apple 2022-03-30
# 5          180    120      12.0     Ninja 2021-12-25
# 6          240     90       8.0    Keurig 2021-08-15
# 7          320    300       5.0   Manduka 2022-01-05
# 8          150     25      15.0   Samsung 2022-06-10
# 9          290     70      10.0     Dyson 2021-10-20
# Inserted 10 documents into MongoDB.
# db.collection.find({ "Category":{"$in":["Home & Kitchen", "Sports"]}, "LaunchDate": { "$gt": "2022-01-01" }, "Discount": { "$gte": 10 } })
# {'Category': {'$in': ['Home & Kitchen', 'Sports']}, 'LaunchDate': {'$gt': '2022-01-01'}, 'Discount': {'$gte': 10}}
# {'Category': {'$in': ['Home & Kitchen', 'Sports']}, 'LaunchDate': {'$gt': '2022-01-01'}, 'Discount': {'$gte': 10}}
# Loaded 10 documents
# Parsing nodes: 100%|██████████| 10/10 [00:00<00:00, 1672.24it/s]
# Generating embeddings: 100%|██████████| 10/10 [00:00<00:00, 38.38it/s]
# Empty Response
